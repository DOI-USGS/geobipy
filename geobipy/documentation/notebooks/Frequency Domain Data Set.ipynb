# %% [markdown]
# # Frequency Domain Data Set

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
from geobipy import FdemData
import numpy as np
from os.path import join

# %% [markdown]
# # Let's read in a frequency domain data set

# %%
FD1 = FdemData()
FD1.read(dataFname=join('supplementary','Data','Resolve2.txt'), systemFname=join('supplementary','Data','FdemSystem2.stm'))

# %% [markdown]
# ### Print out a small summary of the data

# %%
FD1.summary()
# Out:
# 3D Point Cloud:
# Number of Points: :71470
# Name:  Easting
#     Units: m
#     Shape: (71470,)
#     [586852.29 586852.23 586852.17 ... 590160.46 590163.5  590166.53]
# No attached prior
# No attached proposal
# Name:  Northing
#     Units: m
#     Shape: (71470,)
#     [4639119.38 4639122.68 4639125.98 ... 4640082.67 4640082.8  4640082.93]
# No attached prior
# No attached proposal
# Name:  Height
#     Units: m
#     Shape: (71470,)
#     [36.629 37.012 37.349 ... 33.123 33.021 32.917]
# No attached prior
# No attached proposal
#
# Data:          :
# # of Channels: :12
# # of Total Data:857640
# Channel Names:   ['In-Phase 380.0 (Hz)', 'In-Phase 1776.0 (Hz)', 'In-Phase 3345.0 (Hz)', 'In-Phase 8171.0 (Hz)', 'In-Phase 41020.0 (Hz)', 'In-Phase 129550.0 (Hz)', 'Quadrature 380.0 (Hz)', 'Quadrature 1776.0 (Hz)', 'Quadrature 3345.0 (Hz)', 'Quadrature 8171.0 (Hz)', 'Quadrature 41020.0 (Hz)', 'Quadrature 129550.0 (Hz)']

# %% [markdown]
# ### Plot all the data along the specified line

# %%
plt.figure()
ax = FD1.plotLine(30010.0, log=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Or, plot specific channels in the data

# %%
plt.figure()
FD1.plot(channels=[0,11,8], log=10, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="988">

# %% [markdown]
# # Read in a second data set

# %%
FD2 = FdemData()
FD2.read(dataFname=join('supplementary','Data','Resolve1.txt'), systemFname=join('supplementary','Data','FdemSystem1.stm'))

# %% [markdown]
# ### We can create maps of the elevations in two separate figures

# %%
plt.figure()
FD1.mapPlot(dx=50.0, dy=50.0, mask = 200.0, method='ct');plt.axis('equal')

plt.figure()
FD2.mapPlot(dx=50.0, dy=50.0, mask = 200.0, method = 'ct');plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# (662847.39800000004,
#  668366.71100000001,
#  4560053.6550000003,
#  4600646.6500000004)

# %% [markdown]
# ### Or, we can plot both data sets in one figure to see their positions relative to each other.
# #### In this case, I use a 2D scatter plot of the data point co-ordinates, and pass one of the channels as the colour.

# %%
plt.figure()
FD1.scatter2D(s=1.0, c=FD1.getChannel(0))
FD2.scatter2D(s=1.0, c=FD2.getChannel(0), cmap='jet')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Or, I can interpolate the values to create a gridded "map". mapChannel will interpolate the specified channel number.

# %%
plt.figure()
FD1.mapChannel(3, method='ct', dx=200, dy=200, mask=250)
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (584519.28000000003,
#  590166.53000000003,
#  4639079.2400000002,
#  4661808.5999999996)

# %% [markdown]
# ## We can get a specific line from the data set

# %%
print(np.unique(FD1.line))
# Out:
# [ 30010.  30020.  30030. ...,  30100.  39010.  39020.]

# %%
L = FD1.getLine(30010.0)

# %% [markdown]
# ### A summary will now show the properties of the line.

# %%
L.summary()
# Out:
# 3D Point Cloud:
# Number of Points: :6710
# Name:  Easting
#     Units: m
#     Shape: (6710,)
#     [ 586852.29  586852.23  586852.17 ...,  586123.57  586123.2   586122.82]
# No attached prior
# No attached proposal
# Name:  Northing
#     Units: m
#     Shape: (6710,)
#     [ 4639119.38  4639122.68  4639125.98 ...,  4661765.26  4661768.84
#   4661772.42]
# No attached prior
# No attached proposal
# Name:  Height
#     Units: m
#     Shape: (6710,)
#     [ 36.629  37.012  37.349 ...,  28.313  28.218  28.115]
# No attached prior
# No attached proposal
#
# Data:          :
# # of Channels: :12
# # of Total Data:80520
# Channel Names:   ['In-Phase 380.0 (Hz)', 'In-Phase 1776.0 (Hz)', 'In-Phase 3345.0 (Hz)', 'In-Phase 8171.0 (Hz)', 'In-Phase 41020.0 (Hz)', 'In-Phase 129550.0 (Hz)', 'Quadrature 380.0 (Hz)', 'Quadrature 1776.0 (Hz)', 'Quadrature 3345.0 (Hz)', 'Quadrature 8171.0 (Hz)', 'Quadrature 41020.0 (Hz)', 'Quadrature 129550.0 (Hz)']

# %% [markdown]
# ### And we can scatter2D the points in the line.

# %%
plt.figure()
L.scatter2D()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
L.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
