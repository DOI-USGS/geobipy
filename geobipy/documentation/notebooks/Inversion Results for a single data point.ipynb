# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from geobipy import LineResults
import matplotlib.pyplot as plt
from os.path import join
import numpy as np

# %% [markdown]
# ## Results for a single data point

# %%
sysPath = join('supplementary', 'Data')
fName = join('supplementary','run_TimeDomain','30010.0.h5')
LR = LineResults(fName, sysPath=sysPath)

# %%
LR.iDs
# Out:
# array([30000. , 30000.1, 30000.2, ..., 30670.7, 30670.8, 30670.9])

# %%
R = LR.getResults(index=0)

# %%
R.plot(forcePlot=True)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
plt.figure()
R._plotAcceptanceVsIteration()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
R._plotMisfitVsIteration()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
R._plotElevationPosterior()
# Out:
# <img src="data:image/png;base64,..." width="755.909074525203">

# %%
plt.figure()
R._plotNumberOfLayersPosterior()
# Out:
# <img src="data:image/png;base64,..." width="701.8181666066827">

# %%
plt.figure()
R._plotObservedPredictedData()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
R._plotHitmapPosterior()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
plt.subplot(211)
R._plotRelativeErrorPosterior()
plt.subplot(212)
R._plotAdditiveErrorPosterior()
# Out:
# <img src="data:image/png;base64,..." width="722.7272570625813">

# %%
plt.figure()
R._plotLayerDepthPosterior()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.figure()
R.DzHist.plot()
# Out:
# <img src="data:image/png;base64,..." width="860.9090722493893">
