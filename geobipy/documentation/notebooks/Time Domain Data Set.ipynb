# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from os.path import join
import matplotlib.pyplot as plt
import numpy as np
from geobipy.src.classes.core.StatArray import StatArray
from geobipy.src.classes.data.dataset.TdemData import TdemData
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
TD=TdemData()
TD.read(dataFname = [join('supplementary','Data','Skytem_High.txt'), join('supplementary','Data','Skytem_Low.txt')],
        systemFname = [join('supplementary','Data','SkytemHM-SLV.stm'), join('supplementary','Data','SkytemLM-SLV.stm')])

# %%
t0=TD.times(0)
plt.figure()
ax1=plt.subplot(221)
TD.getDataPoint(0).plot()
plt.xlabel('')
plt.subplot(222, sharex=ax1)
TD.getDataPoint(50).plot()
plt.xlabel('')
plt.ylabel('')
plt.subplot(223, sharex=ax1)
TD.getDataPoint(100).plot()
plt.title('')
plt.subplot(224, sharex=ax1)
TD.getDataPoint(200).plot()
plt.ylabel('')
plt.title('')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'')

# %%
plt.figure()
TD.plotWaveform()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
ax=TD.scatter2D(s=1.0,c=TD.getChannel(0,23),equalize=True)
plt.axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/nfoks/Codes/Python/geobipy/geobipy/src/base/customFunctions.py:502: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   H, bins = np.histogram(flat, nBins, normed=True)
# (430343.99879032257, 439562.4012096774, 4194066.798376623, 4197423.201623376)

# %%
plt.figure()
TD.pcolor(log=10)
