# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
from geobipy import StatArray
from geobipy import RectilinearMesh1D
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# %%
x = StatArray(np.cumsum(np.arange(0.0, 10.0)), 'Depth', 'm')

# %%
rm = RectilinearMesh1D(cellEdges=x)

# %%
rm.cellCentres
# Out:
# StatArray([ 0.5,  2. ,  4.5,  8. , 12.5, 18. , 24.5, 32. , 40.5])

# %%
rm.cellEdges
# Out:
# StatArray([ 0.,  1.,  3.,  6., 10., 15., 21., 28., 36., 45.])

# %%
rm.internalCellEdges
# Out:
# StatArray([ 1.,  3.,  6., 10., 15., 21., 28., 36.])

# %%
rm.cellWidths
# Out:
# StatArray([1., 2., 3., 4., 5., 6., 7., 8., 9.])

# %%
plt.figure()
rm.plotGrid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
arr = StatArray(np.random.randn(rm.nCells), "Name", "Units")
rm.pcolor(arr, grid=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Slicing into a 1D Rectilinear Mesh

# %%
rm2 = rm[:-1]
arr = StatArray(np.random.randn(rm2.nCells), "Name", "Units")
plt.figure()
rm2.pcolor(values = arr, grid=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
