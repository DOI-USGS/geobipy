# %% [markdown]
# # Fdem Data Point Class

# %% [markdown]
# ## Fdem Data contains entire data sets
# ## Fdem Data Points can forward model and evaluate themselves
#
# ### FdemData is an extension to the [Data](Data.ipynb) Class
#
# ##### Back to [Main](../../PackageInfo.ipynb)

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

from os.path import join
import numpy as np
import h5py
import matplotlib.pyplot as plt
from geobipy import hdfRead
from geobipy import FdemData
from geobipy import FdemDataPoint
from geobipy import Model1D
from geobipy import StatArray

# %%
# The data file name
dataFile=join('supplementary','Data','Resolve2.txt')
# The EM system file name
systemFile=join('supplementary','Data','FdemSystem2.stm')

# %% [markdown]
# ## Initialize and read an EM data set

# %%
D=FdemData()
D.read(dataFile,systemFile)

# %% [markdown]
# ## Summarize the Data

# %%
D.summary()
# Out:
# 3D Point Cloud:
# Number of Points: :71470
# Name:  Easting
#     Units: m
#     Shape: (71470,)
#     [ 586852.29  586852.23  586852.17 ...,  590160.46  590163.5   590166.53]
# No attached prior
# No attached proposal
# Name:  Northing
#     Units: m
#     Shape: (71470,)
#     [ 4639119.38  4639122.68  4639125.98 ...,  4640082.67  4640082.8
#   4640082.93]
# No attached prior
# No attached proposal
# Name:  Height
#     Units: m
#     Shape: (71470,)
#     [ 36.629  37.012  37.349 ...,  33.123  33.021  32.917]
# No attached prior
# No attached proposal
#
# Data:          :
# # of Channels: :12
# # of Total Data:857640
# Channel Names:   ['In-Phase 380.0 (Hz)', 'In-Phase 1776.0 (Hz)', 'In-Phase 3345.0 (Hz)', 'In-Phase 8171.0 (Hz)', 'In-Phase 41020.0 (Hz)', 'In-Phase 129550.0 (Hz)', 'Quadrature 380.0 (Hz)', 'Quadrature 1776.0 (Hz)', 'Quadrature 3345.0 (Hz)', 'Quadrature 8171.0 (Hz)', 'Quadrature 41020.0 (Hz)', 'Quadrature 129550.0 (Hz)']

# %% [markdown]
# ## Grab a measurement from the data set

# %%
P=D.getDataPoint(0)
P.e -= P.z
P.z[0] = 0.0
P.sys.summary()
P.summary()
plt.figure()
P.plot()
# Out:
# FdemSystem:
# Name:  Frequencies
#     Units: Hz
#     Shape: (6,)
#     [    380.    1776.    3345.    8171.   41020.  129550.]
# No attached prior
# No attached proposal
#
#
# EM Data Point:
# x: :[ 586852.29]
# y: :[ 4639119.38]
# z: :[ 0.]
# e: :[ 1210.211]
# Name:  Fdem Data
#     Units: ppm
#     Shape: (12,)
#     [ 145.3  435.8  260.6 ...,  516.5  405.7  255.7]
# No attached prior
# No attached proposal
# Name:  Predicted Data
#     Units: ppm
#     Shape: (12,)
#     [ 0.  0.  0. ...,  0.  0.  0.]
# No attached prior
# No attached proposal
# Name:  Standard Deviation
#     Units: ppm
#     Shape: (12,)
#     [ 0.  0.  0. ...,  0.  0.  0.]
# No attached prior
# No attached proposal
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## We can forward model the EM response of a 1D layered earth <a href="../Model/Model1D.ipynb">Model1D</a>

# %%
nCells = 19
par = StatArray(np.linspace(0.01, 0.1, nCells), "Conductivity", "$\\frac{S}{m}$")
thk = StatArray(np.ones(nCells) * 10.0)
mod = Model1D(nCells = nCells, parameters=par, thickness=thk)
mod.summary()
#plt.figure()
#mod.plotBlocks()
# Out:
# 1D Model:
# Name:  # of Cells
#     Units:
#     Shape: (1,)
#     [19]
# No attached prior
# No attached proposal
# Top of the model: [ 0.]
# Name:  Thickness
#     Units: m
#     Shape: (19,)
#     [ 10.  10.  10. ...,  10.  10.  nan]
# No attached prior
# No attached proposal
# Name:  Conductivity
#     Units: $\frac{S}{m}$
#     Shape: (19,)
#     [ 0.01   0.015  0.02  ...,  0.09   0.095  0.1  ]
# No attached prior
# No attached proposal
# Name:  Depth
#     Units: m
#     Shape: (19,)
#     [  10.   20.   30. ...,  170.  180.   inf]
# No attached prior
# No attached proposal

# %% [markdown]
# ## Compute and plot the data from the model

# %%
# %%time
P.forward(mod)
# Out:
# CPU times: user 1.9 ms, sys: 27 µs, total: 1.93 ms
# Wall time: 1.93 ms

# %%
P.forward(mod)
plt.figure()
P.plot()
P.plotPredicted()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## The errors are set to zero right now, so lets change that

# %%
# Set the Prior
addErrors = StatArray(np.full(2*P.sys.nFreq, 10.0))
P.p.setPrior('MVNormalLog', addErrors, addErrors)
P.updateErrors(1, P.s[:], 0.1, addErrors[:])

# %% [markdown]
# ## With forward modelling, we can solve for the best fitting halfspace model

# %%
HSconductivity=P.FindBestHalfSpace()
print('Best half space conductivity is ', HSconductivity, ' $S/m$')
plt.figure()
P.plot()
P.plotPredicted()
# Out:
# Best half space conductivity is  0.109411381058  $S/m$
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Compute the misfit between observed and predicted data

# %%
print(P.dataMisfit())
# Out:
# 6.35781509102

# %% [markdown]
# ## Plot the misfits for a range of half space conductivities

# %%
plt.figure()
P.plotHalfSpaceResponses(-6.0,4.0,200)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Compute the sensitivity matrix for a given model

# %%
# %%time
J = P.sensitivity(mod)
# Out:
# CPU times: user 18.2 ms, sys: 511 µs, total: 18.7 ms
# Wall time: 18.9 ms

# %%
J = P.sensitivity(mod)
plt.figure()
J.pcolor(equalize=True);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## We can save the FdemDataPoint to a HDF file

# %%
with h5py.File('FdemDataPoint.h5','w') as hf:
    P.writeHdf(hf, 'fdp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-35a3b1f7fbe7> in <module>()
#       1 with h5py.File('FdemDataPoint.h5','w') as hf:
# ----> 2     P.writeHdf(hf, 'fdp')
#
# /Users/nfoks/Codes/Python/geobipy/geobipy/src/classes/data/datapoint/FdemDataPoint.py in writeHdf(self, parent, myName, index)
#     154         grp = parent.get(myName)
#     155
# --> 156         self.x.writeHdf(grp, 'x',  index=index)
#     157         self.y.writeHdf(grp, 'y',  index=index)
#     158         self.z.writeHdf(grp, 'z',  index=index)
#
# /Users/nfoks/Codes/Python/geobipy/geobipy/src/classes/core/StatArray.py in writeHdf(self, h5obj, myName, index)
#    1079
#    1080         """
# -> 1081         writeNumpy(self,h5obj,myName+'/data',index=index)
#    1082 #        try:
#    1083 #            self.prior.writeHdf(h5obj,myName+'/prior',create=False)
#
# /Users/nfoks/Codes/Python/geobipy/geobipy/src/base/HDF/hdfWrite.py in writeNumpy(arr, h5obj, myName, index)
#      35     # Automatically fills memory from the beginning index in each dimension.
#      36     if (nd == 1):
# ---> 37         h5obj[myName][:arr.size] = arr
#      38         return
#      39
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## And then read it in

# %%
P1=hdfRead.readKeyFromFiles('FdemDataPoint.h5','/','fdp')

# %%
P1.summary()
